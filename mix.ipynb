# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 130963 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.6-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.6-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.6-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# ...

# %%
# 指定Google Drive云端硬盘的根目录，名为drive
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
# 指定當前的工作資料夾
import os
# 此處為google drive中的檔案路徑,drive為之前指定的工作根目錄，要加上
os.chdir("drive/Colab Notebooks")

# %%
os.chdir("dataset")

# %%
os.chdir("0626mix")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
# %matplotlib inline
# %matplotlib inline

# %%
ls
# Out:
# sample_data/

# %%
train_df = pd.read_csv("J_625_2_6003.csv",encoding="utf-8")
a = pd.read_csv("0721mix1.csv",encoding="utf-8")
b = pd.read_csv("0715mix2.csv",encoding="utf-8")

# %%
import numpy as np
train_df["total"]= (np.log(a["total_price"])+ np.log(b["total_price"]))/2

# %%
train_df
# Out:
#            building_id   total_price      total
# 0     X5gsdTWGS3W7JJQB  1.125177e+07  16.207702
# 1     BTshNOJyKHnT2YIT  3.953468e+06  15.200028
# 2     dhdymr0lV8N5kZOT  1.007418e+07  16.068821
# 3     VEwyGGMcD56w5BOc  5.390120e+06  15.537103
# 4     wmUeMoJZfsqaSX9b  1.001079e+06  13.849160
# 5     EtBjGAHmHCe9t7TZ  2.992327e+06  14.907555
# 6     hPNH34vmaZtvBtqc  1.230000e+07  16.325882
# 7     wXjeI38bYDMJJwZC  6.729552e+06  15.718348
# 8     fxZSGX6aPAFKU8W4  1.667655e+06  14.333472
# 9     ewr0Fx6ign87OwaV  3.984034e+06  15.158799
# 10    gHKurnEP4AowzsLg  8.911940e+05  13.700294
# 11    PmLfTgY2FElLrTl0  5.580272e+06  15.552595
# 12    eM2NppIOwzW0o8iy  1.059855e+07  16.191335
# 13    dxxwNun97NH4WTrZ  3.084036e+06  14.847236
# 14    jykBfhh3vdeFUi3H  4.291456e+06  15.259023
# 15    NlXbvdFfmJZf3L18  2.179668e+07  16.922098
# 16    D7jaFWHCzSqLBwdt  9.874143e+05  13.798868
# 17    L10dBBdqGmemweSl  6.609784e+06  15.763320
# 18    OgB0AdiPKlElakKN  1.154957e+06  13.997703
# ...

# %%
train_df["to"]=np.exp(train_df["total"])
train_df
# Out:
#            building_id   total_price      total            to
# 0     X5gsdTWGS3W7JJQB  1.125177e+07  16.207702  1.093743e+07
# 1     BTshNOJyKHnT2YIT  3.953468e+06  15.200028  3.992900e+06
# 2     dhdymr0lV8N5kZOT  1.007418e+07  16.068821  9.519197e+06
# 3     VEwyGGMcD56w5BOc  5.390120e+06  15.537103  5.593430e+06
# 4     wmUeMoJZfsqaSX9b  1.001079e+06  13.849160  1.034222e+06
# 5     EtBjGAHmHCe9t7TZ  2.992327e+06  14.907555  2.980361e+06
# 6     hPNH34vmaZtvBtqc  1.230000e+07  16.325882  1.230950e+07
# 7     wXjeI38bYDMJJwZC  6.729552e+06  15.718348  6.704895e+06
# 8     fxZSGX6aPAFKU8W4  1.667655e+06  14.333472  1.678602e+06
# 9     ewr0Fx6ign87OwaV  3.984034e+06  15.158799  3.831621e+06
# 10    gHKurnEP4AowzsLg  8.911940e+05  13.700294  8.911728e+05
# 11    PmLfTgY2FElLrTl0  5.580272e+06  15.552595  5.680758e+06
# 12    eM2NppIOwzW0o8iy  1.059855e+07  16.191335  1.075988e+07
# 13    dxxwNun97NH4WTrZ  3.084036e+06  14.847236  2.805902e+06
# ...

# %%
train_df = train_df.drop(["total_price"], axis = 1)
train_df = train_df.drop(["total"], axis = 1)
train_df
# Out:
#            building_id            to
# 0     X5gsdTWGS3W7JJQB  1.093743e+07
# 1     BTshNOJyKHnT2YIT  3.992900e+06
# 2     dhdymr0lV8N5kZOT  9.519197e+06
# 3     VEwyGGMcD56w5BOc  5.593430e+06
# 4     wmUeMoJZfsqaSX9b  1.034222e+06
# 5     EtBjGAHmHCe9t7TZ  2.980361e+06
# 6     hPNH34vmaZtvBtqc  1.230950e+07
# 7     wXjeI38bYDMJJwZC  6.704895e+06
# 8     fxZSGX6aPAFKU8W4  1.678602e+06
# 9     ewr0Fx6ign87OwaV  3.831621e+06
# 10    gHKurnEP4AowzsLg  8.911728e+05
# 11    PmLfTgY2FElLrTl0  5.680758e+06
# 12    eM2NppIOwzW0o8iy  1.075988e+07
# 13    dxxwNun97NH4WTrZ  2.805902e+06
# 14    jykBfhh3vdeFUi3H  4.235545e+06
# 15    NlXbvdFfmJZf3L18  2.234466e+07
# 16    D7jaFWHCzSqLBwdt  9.834949e+05
# 17    L10dBBdqGmemweSl  7.013308e+06
# 18    OgB0AdiPKlElakKN  1.199845e+06
# 19    StiWNN1GQrpPBOYt  2.609089e+06
# 20    a016eMAVQKnfwMnt  1.818910e+07
# 21    gsCFcQHnOH3AKMcZ  3.346807e+06
# 22    IbNsDXfsPwSuFpow  5.568834e+06
# 23    EgAVWOVxD1Jy5YkE  1.359414e+06
# ...

# %%
train_df["total_price"]=train_df["to"]

# %%
train_df = train_df.drop(["to"], axis = 1)
train_df
# Out:
#            building_id   total_price
# 0     X5gsdTWGS3W7JJQB  1.093743e+07
# 1     BTshNOJyKHnT2YIT  3.992900e+06
# 2     dhdymr0lV8N5kZOT  9.519197e+06
# 3     VEwyGGMcD56w5BOc  5.593430e+06
# 4     wmUeMoJZfsqaSX9b  1.034222e+06
# 5     EtBjGAHmHCe9t7TZ  2.980361e+06
# 6     hPNH34vmaZtvBtqc  1.230950e+07
# 7     wXjeI38bYDMJJwZC  6.704895e+06
# 8     fxZSGX6aPAFKU8W4  1.678602e+06
# 9     ewr0Fx6ign87OwaV  3.831621e+06
# 10    gHKurnEP4AowzsLg  8.911728e+05
# 11    PmLfTgY2FElLrTl0  5.680758e+06
# 12    eM2NppIOwzW0o8iy  1.075988e+07
# 13    dxxwNun97NH4WTrZ  2.805902e+06
# 14    jykBfhh3vdeFUi3H  4.235545e+06
# 15    NlXbvdFfmJZf3L18  2.234466e+07
# 16    D7jaFWHCzSqLBwdt  9.834949e+05
# 17    L10dBBdqGmemweSl  7.013308e+06
# 18    OgB0AdiPKlElakKN  1.199845e+06
# 19    StiWNN1GQrpPBOYt  2.609089e+06
# 20    a016eMAVQKnfwMnt  1.818910e+07
# 21    gsCFcQHnOH3AKMcZ  3.346807e+06
# 22    IbNsDXfsPwSuFpow  5.568834e+06
# 23    EgAVWOVxD1Jy5YkE  1.359414e+06
# ...

# %%
train_df.to_csv('./0721mix8.csv', sep=',', encoding='utf-8',index=0)
